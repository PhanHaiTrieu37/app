# %%
import pandas as pd

# %%
dt = pd.read_csv('./data/orginal_sales_data_edit.csv', encoding='utf-8', header=0)
dt.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003  Shipped       1         2     2003  ...
# 1    5/7/2003  Shipped       2         5     2003  ...
# 2    7/1/2003  Shipped       3         7     2003  ...
# 3   8/25/2003  Shipped       3         8     2003  ...
# 4  10/10/2003  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
import firebase_admin
from firebase_admin import credentials, firestore

# %%
if not firebase_admin._apps:
    cred = credentials.Certificate(
        "./iuh-20089981-6c1f2-firebase-adminsdk-otxhy-9dcdeecc3f.json")
    app = firebase_admin.initialize_app(cred)

# %%
dbFIrestore = firestore.client()

# %%
for it in dt.to_dict(orient='records'): 
    doc_ref = dbFIrestore.collection("tbl-20012011").document()
    doc_ref.set(it)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 3
#       1 for it in dt.to_dict(orient='records'):
#       2     doc_ref = dbFIrestore.collection("tbl-20012011").document()
# ----> 3     doc_ref.set(it)
#
# File c:\Users\84962\AppData\Local\Programs\Python\Python38-32\lib\site-packages\google\cloud\firestore_v1\document.py:167, in DocumentReference.set(self, document_data, merge, retry, timeout)
#     109 """Create / replace / merge a document in the Firestore database.
#     110
#     111 - To "upsert" a document (create if it doesn't exist, replace completely
#    (...)
#     164     result contains an ``update_time`` field.
#     165 """
#     166 batch, kwargs = self._prep_set(document_data, merge, retry, timeout)
# --> 167 write_results = batch.commit(**kwargs)
#     168 return _first_write_result(write_results)
#
# ...
